# %%
import pandas as pd

# %%
df = pd.read_parquet("data/spx_vol_surface_history_full_data_23.parquet").dropna().reset_index(names="date")
df.head()
# Out:
#         date  ttm_one_month_moneyness_pt_seven  \
# 0 2000-01-03                      6.194064e-02
# 1 2000-01-04                      1.363700e-01
# 2 2000-01-05                      9.418156e-18
# 3 2000-01-06                      1.702120e-16
# 4 2000-01-07                      7.347157e-01
#
#    ttm_one_month_moneyness_pt_eightfive  ttm_one_month_moneyness_pt_one  \
# 0                              0.312185                        0.204530
# 1                              0.320018                        0.240132
# 2                              0.342766                        0.229619
# 3                              0.154186                        0.186524
# 4                              0.400736                        0.205539
#
#    ttm_one_month_moneyness_pt_oneonefive  ttm_one_month_moneyness_pt_onethree  \
# 0                               0.130964                         0.000000e+00
# 1                               0.144813                         5.976089e-17
# ...

# %%
df.loc[5001]
# Out:
# date                                       2019-11-20 00:00:00
# ttm_one_month_moneyness_pt_seven                       0.04943
# ttm_one_month_moneyness_pt_eightfive                  0.252494
# ttm_one_month_moneyness_pt_one                        0.103751
# ttm_one_month_moneyness_pt_oneonefive                     -0.0
# ttm_one_month_moneyness_pt_onethree                        0.0
# ttm_three_month_moneyness_pt_seven                    0.272567
# ttm_three_month_moneyness_pt_eightfive                 0.23731
# ttm_three_month_moneyness_pt_one                      0.130813
# ttm_three_month_moneyness_pt_oneonefive                0.05356
# ttm_three_month_moneyness_pt_onethree                      0.0
# ttm_six_month_moneyness_pt_seven                      0.280567
# ttm_six_month_moneyness_pt_eightfive                  0.228693
# ttm_six_month_moneyness_pt_one                        0.147937
# ttm_six_month_moneyness_pt_oneonefive                  0.08565
# ...
